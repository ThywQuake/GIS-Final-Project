# %%
import geopandas as gpd

# Read in the data

data=gpd.read_file('./china.json')

# %%
data
# Out:
#        adcode      name adchar  childrenNum     level              parent  \
# 0      110000       北京市   None         16.0  province  {'adcode': 100000}
# 1      120000       天津市   None         16.0  province  {'adcode': 100000}
# 2      130000       河北省   None         11.0  province  {'adcode': 100000}
# 3      140000       山西省   None         11.0  province  {'adcode': 100000}
# 4      150000    内蒙古自治区   None         12.0  province  {'adcode': 100000}
# 5      210000       辽宁省   None         14.0  province  {'adcode': 100000}
# 6      220000       吉林省   None          9.0  province  {'adcode': 100000}
# 7      230000      黑龙江省   None         13.0  province  {'adcode': 100000}
# 8      310000       上海市   None         16.0  province  {'adcode': 100000}
# 9      320000       江苏省   None         13.0  province  {'adcode': 100000}
# 10     330000       浙江省   None         11.0  province  {'adcode': 100000}
# 11     340000       安徽省   None         16.0  province  {'adcode': 100000}
# ...

# %%
import pandas as pd

data.to_file('china', driver='ESRI Shapefile')
# Out:
# C:\Windows\Temp\ipykernel_4900\3817440532.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   data.to_file('china', driver='ESRI Shapefile')
